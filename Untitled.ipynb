# %%
import sqlalchemy as sqla
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("states.csv")

# %%
df
# Out:
#    State ID                                 State
# 0       U01             Andaman & Nicobar Islands
# 1       S01                        Andhra Pradesh
# 2       S02                     Arunachal Pradesh
# 3       S03                                 Assam
# 4       S04                                 Bihar
# 5       U02                            Chandigarh
# 6       S26                          Chhattisgarh
# 7       U03  Dadra & Nagar Haveli and Daman & Diu
# 8       S05                                   Goa
# 9       S06                               Gujarat
# 10      S07                               Haryana
# 11      S08                      Himachal Pradesh
# 12      U08                     Jammu and Kashmir
# 13      S27                             Jharkhand
# 14      S10                             Karnataka
# 15      S11                                Kerala
# 16      U09                                Ladakh
# 17      U06                           Lakshadweep
# ...

# %%
engine = sqla.create_engine("mysql+pymysql://root:ashu2622@localhost/loksabha")

try:
    
    with engine.connect() as connection:
         print("SQLAlchemy engine created and connected successfully!")

except SQLAlchemyError as e:
    print(f"Connection failed. Error: {e}")
# Out:
# SQLAlchemy engine created and connected successfully!

# %%
df.to_sql(
    name="stats",
    con=engine,
    if_exists="replace",
    index=False
)
# Out:
# 36

# %%
df1=pd.read_csv("constituencywise_details.csv")

# %%
df1
# Out:
#       S.N.            Candidate                        Party  EVM Votes  \
# 0        1    DR JITENDRA SINGH       Bharatiya Janata Party     566833
# 1        2         CH LAL SINGH     Indian National Congress     444151
# 2        3  GHULAM MOHD SAROORI                  Independent      39519
# 3        4           MEHRAJ DIN                  Independent       9055
# 4        5           AMIT KUMAR          Bahujan Samaj Party       8559
# ...    ...                  ...                          ...        ...
# 8897     7        JANARDAN GOND                  Independent       2672
# 8898     8            RAM MILAN  Sardar Patel Siddhant Party       1699
# 8899     9         RINKU SAHANI           Rashtra Dharak Dal       1681
# 8900    10               JAGRAM                  Independent       1514
# 8901    11                 NOTA            None of the Above      12862
#
#       Postal Votes  Total Votes  % of Votes Constituency ID
# ...

# %%
df1.to_sql(
    name="constituencywise_details",
    con=engine,
    if_exists="replace",
    index=False
)
# Out:
# 8902

# %%
df2=pd.read_csv("constituencywise_results.csv")

# %%
df2
# Out:
#      S.No Parliament Constituency Constituency Name  \
# 0     222             ADILABAD(1)          ADILABAD
# 1     162                AGRA(18)              AGRA
# 2      33        AHMEDABADEAST(7)     AHMEDABADEAST
# 3      34        AHMEDABADWEST(8)     AHMEDABADWEST
# 4       6          AHMEDNAGAR(37)        AHMEDNAGAR
# ..    ...                     ...               ...
# 538     1               WARDHA(8)            WARDHA
# 539    26              WAYANAD(4)           WAYANAD
# 540   237            WESTDELHI(6)         WESTDELHI
# 541     1     YAVATMAL-WASHIM(14)   YAVATMAL-WASHIM
# 542    90            ZAHIRABAD(5)         ZAHIRABAD
#
#                  Winning Candidate  Total Votes  Margin Constituency ID  \
# 0                     GODAM NAGESH       568168   90652            S291
# 1            PROF S P SINGH BAGHEL       599397  271294           S2418
# 2    HASMUKHBHAI PATEL (H.S.PATEL)       770459  461755            S067
# ...

# %%
df2.to_sql(
    name="constituencywise_results",
    con=engine,
    if_exists="replace",
    index=False
)
# Out:
# 543

# %%
df3=pd.read_csv("partywise_results.csv")
df4=pd.read_csv("statewise_results.csv")

# %%
df3.to_sql(
    name="partywise_results",
    con=engine,
    if_exists="replace",
    index=False
)
# Out:
# 42

# %%
df4.to_sql(
    name="statewise_results",
    con=engine,
    if_exists="replace",
    index=False
)
# Out:
# 543

# %%
engine.dispose()
